# %% [markdown]
# <a href="https://colab.research.google.com/github/GurungVinivesh/Employee_dis_analysis/blob/main/Employee_descriptive_analysis1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Using Descriptive Statistics for Employees** <br>
# A minor case study of how the descriptive statistics works

# %% [markdown]
# In this case study we will perform some of the following tasks as mention below:
#
# 1.   Load and study the data
# 2.   visualize the disturbances of ratings and compensations
# 3.   Subset of the data based on the thresholds

# %% [markdown]
# # **TASK 1 :**
#
# Load the data and study the data.
# * The number of employees.
# * The number of features.
# * The types of features.

# %%
#First Load numpy and pandas for manipulating numbers and dataframes
#Then load matplotlib.pyplot and seaborn for data visualization

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#now use the pandas to read the csv file named "Emplyee Dataset.csv"

emp_data = pd.read_csv('/content/Employee Dataset.csv')

# %%
#Take brief look at the data

emp_data.tail()  #Here we used tail() which will print the last 10 data of the dataframe
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 45  45      O   25               5                 8    1601
# 46  46     AB   29               4                 3    2179
# 47  47      B   30               4                 6    1484
# 48  48      A   30               5                 6    2065
# 49  49      A   29               6                 9    1950

# %%
#Now check the dimensions of the dataframe

emp_data.shape
# Out:
# (50, 6)

# %%
#Get the column name from the dataframe

emp_data.columns
# Out:
# Index(['id', 'groups', 'age', 'healthy_eating', 'active_lifestyle', 'salary'], dtype='object')

# %%
#Get the basic information from the dataframe

emp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                50 non-null     int64
#  1   groups            50 non-null     object
#  2   age               50 non-null     int64
#  3   healthy_eating    50 non-null     int64
#  4   active_lifestyle  50 non-null     int64
#  5   salary            50 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 2.5+ KB

# %% [markdown]
# ***Observations from Task 1:***
#
# There are total of 50 rows and 6 columns present in the dataframe.<br>
# Each row contain an employee specification of certain employee in the company.<br>
# The feature of the data set are: <br>
# 1.   The id of the employees.
# 2.   Their resepective groups and age.
# 3.   Their habits such as healthy eating and active lifestyle.
# 4.   Their Salary.

# %% [markdown]
# # **TASK 2 :**<br>
#
# We will now visualize the distributions of employee ratings and compensations.<br>
# We Will create the following plots:
# *   A scatter plot of employee age and employee salary, healthy eating and active lifestyle, healthy eating and salary.
# *   A count plot of groups.
# *   A histogram for employee salary.

# %%
#Create a scatter plot of the "age" and "salary" features from emp_data

plt.figure(figsize = (9,4))

sns.scatterplot(data = emp_data, x = 'age', y = 'salary', color = 'b', edgecolor = 'k', alpha = 0.7)

plt.title('Scatter Plot of Age and Salary', fontsize = 15)
plt.xlabel('Age', fontsize = 15)
plt.ylabel('Salary', fontsize = 15)
plt.show()

# %% [markdown]
# *Observation:* <br>
# As we can see in the above graph there is a relationship between age and salary of employees.<br>
# As the age increases the salary also increases, though there are some cases of outliers present in it.

# %%
#Create a scatter plot for "healthy_eating" and "active_lifestyle" features from the emp_data

plt.figure(figsize = (9,4))

sns.scatterplot(data = emp_data, x = 'healthy_eating', y = 'active_lifestyle', color = 'g', edgecolor = 'k', alpha = 0.7)

plt.title('Scatter Plot of Healthy eating and Active lifestyle', fontsize = 15)
plt.xlabel('Healthy eating', fontsize = 15)
plt.ylabel('Active lifestyle', fontsize = 15)
plt.show()

# %% [markdown]
# *Observations:* <br>
# As we can see in the above scatter plot that the healthy eating and active lifestyle are forming a general relationship between each other.<br>
# As the healthy eating is increasing the active lifestyle is also increasing along with it, although there are some cases of outliers present in it.

# %%
#Now we will create a scatter plot of "healthy_eating" and "salary" feature

plt.figure(figsize = (9,4))

sns.scatterplot(data = emp_data, x = 'healthy_eating', y = 'salary', color = 'c', edgecolor = 'r', alpha = .8)

plt.title('Scatter Plot of Health eating and Salary', fontsize = 15)
plt.xlabel('Healthy eating', fontsize = 15)
plt.ylabel('Salary', fontsize = 15)
plt.show()

# %% [markdown]
# *Observations:*<br>
# As we can see there, in general there is a relationship between healthy eating and salary. <br>
# As the healthy eating is increasing the salary is also increasing.

# %%
#Now create a count plot of the "groups" features

plt.figure(figsize = (9,4))

sns.countplot(data = emp_data, x = 'groups', edgecolor = 'k', alpha = 0.7)

plt.title('Count Plot of Groups', fontsize = 15)
plt.xlabel('Groups', fontsize = 15)
plt.ylabel('Count', fontsize = 15)
plt.show()

# %% [markdown]
# *Observation:* <br>
# According to the count plot above, we can clearly see the most of the employees belong to either the group A or group 0, While the group A having the most of the frequency present.

# %%
#Create a histogram of the "salary" feature

plt.figure(figsize = (9,4))

sns.histplot(data = emp_data, x = 'salary', color = 'b', edgecolor = 'k', alpha = .8, bins =10)

plt.title('Histogram of Salary', fontsize = 15)
plt.xlabel('Salary', fontsize = 15)
plt.ylabel('Count', fontsize = 15)
plt.show()

# %% [markdown]
# *Observations:* <br>
# We see that in the histogram above that the salaries are not uniform, which is not exactly a discrepancy. <br>
# But we do observe that there are some employees with salaries on the extremeties of the histogram. <br>
# Based on the above observation from histogram we can say that there are not much employee with highest earning.

# %% [markdown]
# ***Observation from Task 2 :*** <br>
# 1.   As the age of employee increases the salary also increases, in most of the cases.
# 2.   Also as the emplyees healthy eating increases, salaries of those employees also increases, and are positively correlated.
# 3.   However, the employee salary values are more spread out.
# 4.   An employee of healthy eating greater than 8 can be taken as 8.
# 5.   An employee having salary <= 1000 can be considered as a lower salary.

# %% [markdown]
# # **TASK 3 :**<br>
# Subset the data based on threshold. <br>
#
# We will now make the subset of the data frame based on following:
#
# *   Employees with healthy eating greater than 8
# *   Employees with salary less than 1000
# *   Employees with healthy eating greater than 8 and salary less than 1000

# %%
#Employees with healthy eating greater than 8

hea_eat = emp_data[emp_data['healthy_eating'] > 8]
hea_eat
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 26  26      A   62               9                 6     700

# %%
#Employees with salary less than 1000

sal = emp_data[emp_data['salary'] < 1000]
sal
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 3    3      O   24               3                 6     902
# 15  15      B   26               3                 8     662
# 18  18      A   27               2                 6     779
# 26  26      A   62               9                 6     700
# 32  32      A   22               3                 8     662
# 35  35      O   27               2                 4     785
# 38  38     AB   26               3                 7     670
# 39  39      B   29               2                 6     779
# 43  43      O   23               4                10     556

# %%
#Now finding the employees with healthy habits more than 8 and salary less than 1000

combo = emp_data[(emp_data['healthy_eating'] > 8) & (emp_data['salary'] < 1000)]

# %%
combo
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 26  26      A   62               9                 6     700

# %% [markdown]
# *Observation:*<br>
# The only employee who is facing descrepancy in salary as compared to healthy eating is employee having id = 26.<br>
# The employee having id = 26 has only salary of 700.

# %% [markdown]
# # **Final Conclusion** <br>
# From the given data we can simply indentify how the data is distributed, through the use  of visualization. <br>
# We can simply do preliminary analyses by subsetting the data sets, by keeping in mind the thresholds and conditions.
